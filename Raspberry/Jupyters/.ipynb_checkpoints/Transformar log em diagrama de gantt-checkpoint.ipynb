# %% [markdown]
# # Transformar log em diagrama de gantt

# %% [markdown]
# Esse jupyter apenas lê um Log gerado pelo processarEmTempoReal.py e transforma num diagrama de gantt.

# %%
import matplotlib.pyplot as plt
import numpy as np
from random import randint

# %%
#DEFININDO ALGUNS PARÂMETROS DO GRÁFICO
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
params = {
    'figure.figsize': [12, 5.5], 
    'axes.labelsize': 14,
    'axes.titlesize':18, 
    'font.size': 18,
    'legend.fontsize': 12, 
    'xtick.labelsize': 10, 
    'ytick.labelsize': 10,
    'axes.axisbelow': True
}
plt.rcParams.update(params)

# %%
def corAleatoria():
    return "#" + str(randint(10,99)) + str(randint(10,99)) + str(randint(10,99))

# %% [markdown]
# ### Lendo

# %%
# DEFININDO O ARQUIVO LOG QUE QUERO LER
arquivoLog = "/home/pi/Programming/IC2019/Raspberry/Resultados/Logs/logProcessamento_1595025719.7548664.txt"

# CRIANDO O DICIONARIO QUE VAI GUARDAR OS DADOS
dictGeral = {}

# LENDO O ARQUIVO LINHA POR LINHA
objFile     = open(arquivoLog, 'r') 
arrayLinhas = objFile.readlines()
for i, linhaAtual in enumerate(arrayLinhas):         
    
    # SEPARANDO POR ESPACOS
    splits = linhaAtual.split(" ")
    
    # DEFININDO AS VARIAVEIS
    idJanela  = splits[0][4:-2]
    comando   = str(splits[1]+splits[2][:-1]).lower()
    timestamp = splits[-1][:-1]
    
    # COLOCANDO NO DICIONARIO - se for inicio de gravacao a gnt tem que criar a chave do 0
    if comando == "iniciogravacao":
        dictGeral[idJanela] = {comando: float(timestamp)}
    else:
        dictGeral[idJanela][comando] = float(timestamp)
        
    # PEGANDO O TEMPO DE REFERENCIA PRA SER O 0:
    if i == 0 and comando == "iniciogravacao":
        tempoReferencia = float(timestamp)

# %% [markdown]
# ### Printando

# %%
caminhoSalvar = "/home/pi/Programming/IC2019/Raspberry/Resultados/"
tempoJanela   = 0.2
deJanela      = 50
ateJanela     = deJanela + 19
yTicks        = []

for i, chave in enumerate(dictGeral):
    
    # VERIFICANDO SE DEVO PLOTAR MSM ISSO AI
    if int(chave) < deJanela or int(chave) > ateJanela:
        continue
    
    # AJUSTANDO O EIXO X DA ITERACAO ATUAL
    inicioGravacao      = dictGeral[chave]["iniciogravacao"] - tempoReferencia
    fimGravacao         = dictGeral[chave]["fimgravacao"] - tempoReferencia
    inicioProcessamento = dictGeral[chave]["inicioprocessamento"] - tempoReferencia
    fimProcessamento    = dictGeral[chave]["fimprocessamento"] - tempoReferencia
    
    # DEFININDO A COR
    corAtual = corAleatoria()
    
    # COLOCANDO A ITERACAO ATUAL NO YTICKS
    yTicks.append(chave)
    
    # PLOTANDO
    if i == deJanela:
        plt.plot([inicioGravacao, fimGravacao], [i, i], "-", color="black", label="Gravação (fluxo principal)")
        plt.plot([inicioProcessamento, fimProcessamento], [i, i], "--", color="black", label="Processamento (threads individuais)")
    else:
        plt.plot([inicioGravacao, fimGravacao], [i, i], "-", color=corAtual)
        plt.plot([inicioProcessamento, fimProcessamento], [i, i], "--", color=corAtual)

# AJUSTANDO MAIS PARAMETROS
plt.title("Diagrama de Gantt - Raspberry")
plt.ylabel("Janela")
plt.xlabel("Tempo (s)")
plt.legend()
#plt.xlim(-tempoJanela, fimProcessamento)
#plt.xticks(ticks=np.arange(-tempoJanela, fimProcessamento+tempoJanela, tempoJanela), rotation=45)
plt.yticks(ticks=np.arange(deJanela-1, ateJanela), labels=yTicks)
plt.gca().invert_yaxis()
plt.grid(alpha=0.4)
plt.savefig(caminhoSalvar+"diagramaGantt_raspberry.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
#  '35': {'iniciogravacao': 1595025334.1988525,
#   'fimgravacao': 1595025334.3900356,
#   'inicioprocessamento': 1595025334.3907301,
#   'fimprocessamento': 1595025334.6502976},
#  '36': {'iniciogravacao': 1595025334.2631245,
#   'fimgravacao': 1595025334.4544322,
#   'inicioprocessamento': 1595025334.4559357,
#   'fimprocessamento': 1595025334.6710978},
#  '37': {'iniciogravacao': 1595025334.4607394,
#   'fimgravacao': 1595025334.7173204,
#   'inicioprocessamento': 1595025334.7178373,
#   'fimprocessamento': 1595025335.0107648},
#  '38': {'iniciogravacao': 1595025334.5897458,
#   'fimgravacao': 1595025334.7823904,
#   'inicioprocessamento': 1595025334.783553,
#   'fimprocessamento': 1595025335.1034784},
#  '39': {'iniciogravacao': 1595025334.7184057,
#   'fimgravacao': 1595025334.9095857,
#   'inicioprocessamento': 1595025334.9101598,
#   'fimprocessamento': 1595025335.204613},
#  '40': {'iniciogravacao': 1595025334.7843525,
#   'fimgravacao': 1595025334.9743798,
#   'inicioprocessamento': 1595025334.9753735,
#   'fimprocessamento': 1595025335.2250438},
#  '41': {'iniciogravacao': 1595025334.9818337,
#   'fimgravacao': 1595025335.2378073,
#   'inicioprocessamento': 1595025335.2382936,
#   'fimprocessamento': 1595025335.428981},
#  '42': {'iniciogravacao': 1595025335.1101463,
#   'fimgravacao': 1595025335.3021774,
#   'inicioprocessamento': 1595025335.3027153,
#   'fimprocessamento': 1595025335.5198803},
#  '43': {'iniciogravacao': 1595025335.2388506,
#   'fimgravacao': 1595025335.4301383,
#   'inicioprocessamento': 1595025335.4331546,
#   'fimprocessamento': 1595025335.7304657},
#  '44': {'iniciogravacao': 1595025335.3032007,
#   'fimgravacao': 1595025335.4947376,
#   'inicioprocessamento': 1595025335.4954855,
#   'fimprocessamento': 1595025335.750595},
#  '45': {'iniciogravacao': 1595025335.4994087,
#   'fimgravacao': 1595025335.7556922,
#   'inicioprocessamento': 1595025335.7561705,
#   'fimprocessamento': 1595025335.9584389},
#  '46': {'iniciogravacao': 1595025335.6286323,
#   'fimgravacao': 1595025335.8200288,
#   'inicioprocessamento': 1595025335.8205876,
#   'fimprocessamento': 1595025336.0532496},
#  '47': {'iniciogravacao': 1595025335.7567205,
#   'fimgravacao': 1595025335.947896,
#   'inicioprocessamento': 1595025335.948554,
#   'fimprocessamento': 1595025336.2115796},
#  '48': {'iniciogravacao': 1595025335.8210678,
#   'fimgravacao': 1595025336.0126045,
#   'inicioprocessamento': 1595025336.013502,
#   'fimprocessamento': 1595025336.231106},
#  '49': {'iniciogravacao': 1595025336.0173655,
#   'fimgravacao': 1595025336.2737274,
#   'inicioprocessamento': 1595025336.2742183,
#   'fimprocessamento': 1595025336.5508547},
#  '50': {'iniciogravacao': 1595025336.1463494,
#   'fimgravacao': 1595025336.338125,
#   'inicioprocessamento': 1595025336.338687,
#   'fimprocessamento': 1595025336.6927238},
#  '51': {'iniciogravacao': 1595025336.2748241,
#   'fimgravacao': 1595025336.4658458,
#   'inicioprocessamento': 1595025336.466412,
#   'fimprocessamento': 1595025336.7622912},
#  '52': {'iniciogravacao': 1595025336.3391695,
#   'fimgravacao': 1595025336.5302072,
#   'inicioprocessamento': 1595025336.5316663,
#   'fimprocessamento': 1595025336.8045065}}
