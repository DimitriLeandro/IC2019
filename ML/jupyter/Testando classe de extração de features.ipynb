# %% [markdown]
# # Testando a classe de extração de features

# %% [markdown]
# Esse jupyter tem o objetivo de testar a classe de extração de features. Ela foi totalmente implementada no jupyter "Implementação de classe para extração de features - SESA Dataset", mas aqui nós vamos testar o arquivo .py que contém a classe.
#
# Para usar a classe é muito simples. Basta ter uma pasta com os arquivos wav que se deseja extrair as features (essa pasta só deve ter arquivos wav, nada mais), e definir os parâmetros iniciais, que são:
#
# 1) Frequência de amostragem dos áudios da pasta;
#
# 2) O tamanho do janelamento e da sobreposição que se deseja (em qtd de frames, não em segundos);
#
# 3) Se deve ser feito o escalonamento das features após a extração (default True);
#
# 4) Quantidade de componentes principais do PCA para fazer a redução de dimensinalidade (default None)
#
# Depois disso, basta instânciar um objeto da classe com esses parâmetros que o construtor se encarregará de fazer todo o trabalho. Ao final, haverá um arquivo CSV dentro da pasta em questão.

# %%
import sys
sys.path.append('/home/dimi/Programming/IC2019/ML/python')
from extrairFeaturesClass import ExtrairFeatures

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Definindo parâmetros iniciais

# %% [markdown]
# Como definido no momento em que a classes estava sendo criada, frameLength é o tamanho do menor áudio do dataset, overlapLength é a metade do frameLength.

# %%
diretorio      = "/home/dimi/Downloads/SESA/train/"
freqAmostragem = 16000
frameLength    = 17145
overlapLength  = 8572
escalonamento  = True
nDimensoes     = 53

ExtrairFeatures(diretorio, freqAmostragem, frameLength, overlapLength, escalonamento, nDimensoes)
# Out:
# Extraindo features do arquivo 1 de 480 -> 0.20833333333333334%
# Extraindo features do arquivo 2 de 480 -> 0.4166666666666667%
# Extraindo features do arquivo 3 de 480 -> 0.625%
# Extraindo features do arquivo 4 de 480 -> 0.8333333333333334%
# Extraindo features do arquivo 5 de 480 -> 1.0416666666666665%
# Extraindo features do arquivo 6 de 480 -> 1.25%
# Extraindo features do arquivo 7 de 480 -> 1.4583333333333333%
# Extraindo features do arquivo 8 de 480 -> 1.6666666666666667%
# Extraindo features do arquivo 9 de 480 -> 1.875%
# Extraindo features do arquivo 10 de 480 -> 2.083333333333333%
# Extraindo features do arquivo 11 de 480 -> 2.2916666666666665%
# Extraindo features do arquivo 12 de 480 -> 2.5%
# Extraindo features do arquivo 13 de 480 -> 2.7083333333333335%
# Extraindo features do arquivo 14 de 480 -> 2.9166666666666665%
# Extraindo features do arquivo 15 de 480 -> 3.125%
# Extraindo features do arquivo 16 de 480 -> 3.3333333333333335%
# Extraindo features do arquivo 17 de 480 -> 3.5416666666666665%
# Extraindo features do arquivo 18 de 480 -> 3.75%
# Extraindo features do arquivo 19 de 480 -> 3.958333333333333%
# Extraindo features do arquivo 20 de 480 -> 4.166666666666666%
# Extraindo features do arquivo 21 de 480 -> 4.375%
# Extraindo features do arquivo 22 de 480 -> 4.583333333333333%
# Extraindo features do arquivo 23 de 480 -> 4.791666666666667%
# Extraindo features do arquivo 24 de 480 -> 5.0%
# Extraindo features do arquivo 25 de 480 -> 5.208333333333334%
# Extraindo features do arquivo 26 de 480 -> 5.416666666666667%
# Extraindo features do arquivo 27 de 480 -> 5.625%
# Extraindo features do arquivo 28 de 480 -> 5.833333333333333%
# Extraindo features do arquivo 29 de 480 -> 6.041666666666667%
# Extraindo features do arquivo 30 de 480 -> 6.25%
# Extraindo features do arquivo 31 de 480 -> 6.458333333333334%
# Extraindo features do arquivo 32 de 480 -> 6.666666666666667%
# Extraindo features do arquivo 33 de 480 -> 6.875000000000001%
# Extraindo features do arquivo 34 de 480 -> 7.083333333333333%
# Extraindo features do arquivo 35 de 480 -> 7.291666666666667%
# Extraindo features do arquivo 36 de 480 -> 7.5%
# Extraindo features do arquivo 37 de 480 -> 7.708333333333334%
# Extraindo features do arquivo 38 de 480 -> 7.916666666666666%
# Extraindo features do arquivo 39 de 480 -> 8.125%
# Extraindo features do arquivo 40 de 480 -> 8.333333333333332%
# Extraindo features do arquivo 41 de 480 -> 8.541666666666666%
# Extraindo features do arquivo 42 de 480 -> 8.75%
# Extraindo features do arquivo 43 de 480 -> 8.958333333333334%
# Extraindo features do arquivo 44 de 480 -> 9.166666666666666%
# Extraindo features do arquivo 45 de 480 -> 9.375%
# Extraindo features do arquivo 46 de 480 -> 9.583333333333334%
# Extraindo features do arquivo 47 de 480 -> 9.791666666666666%
# Extraindo features do arquivo 48 de 480 -> 10.0%
# Extraindo features do arquivo 49 de 480 -> 10.208333333333334%
# Extraindo features do arquivo 50 de 480 -> 10.416666666666668%
# Extraindo features do arquivo 51 de 480 -> 10.625%
# Extraindo features do arquivo 52 de 480 -> 10.833333333333334%
# Extraindo features do arquivo 53 de 480 -> 11.041666666666666%
# Extraindo features do arquivo 54 de 480 -> 11.25%
# Extraindo features do arquivo 55 de 480 -> 11.458333333333332%
# Extraindo features do arquivo 56 de 480 -> 11.666666666666666%
# Extraindo features do arquivo 57 de 480 -> 11.875%
# Extraindo features do arquivo 58 de 480 -> 12.083333333333334%
# Extraindo features do arquivo 59 de 480 -> 12.291666666666666%
# Extraindo features do arquivo 60 de 480 -> 12.5%
# Extraindo features do arquivo 61 de 480 -> 12.708333333333332%
# Extraindo features do arquivo 62 de 480 -> 12.916666666666668%
# Extraindo features do arquivo 63 de 480 -> 13.125%
# Extraindo features do arquivo 64 de 480 -> 13.333333333333334%
# Extraindo features do arquivo 65 de 480 -> 13.541666666666666%
# Extraindo features do arquivo 66 de 480 -> 13.750000000000002%
# Extraindo features do arquivo 67 de 480 -> 13.958333333333334%
# Extraindo features do arquivo 68 de 480 -> 14.166666666666666%
# Extraindo features do arquivo 69 de 480 -> 14.374999999999998%
# Extraindo features do arquivo 70 de 480 -> 14.583333333333334%
# Extraindo features do arquivo 71 de 480 -> 14.791666666666666%
# Extraindo features do arquivo 72 de 480 -> 15.0%
# Extraindo features do arquivo 73 de 480 -> 15.208333333333332%
# Extraindo features do arquivo 74 de 480 -> 15.416666666666668%
# Extraindo features do arquivo 75 de 480 -> 15.625%
# Extraindo features do arquivo 76 de 480 -> 15.833333333333332%
# Extraindo features do arquivo 77 de 480 -> 16.041666666666668%
# Extraindo features do arquivo 78 de 480 -> 16.25%
# Extraindo features do arquivo 79 de 480 -> 16.458333333333332%
# Extraindo features do arquivo 80 de 480 -> 16.666666666666664%
# Extraindo features do arquivo 81 de 480 -> 16.875%
# Extraindo features do arquivo 82 de 480 -> 17.083333333333332%
# Extraindo features do arquivo 83 de 480 -> 17.291666666666668%
# Extraindo features do arquivo 84 de 480 -> 17.5%
# Extraindo features do arquivo 85 de 480 -> 17.708333333333336%
# Extraindo features do arquivo 86 de 480 -> 17.916666666666668%
# Extraindo features do arquivo 87 de 480 -> 18.125%
# Extraindo features do arquivo 88 de 480 -> 18.333333333333332%
# Extraindo features do arquivo 89 de 480 -> 18.541666666666668%
# Extraindo features do arquivo 90 de 480 -> 18.75%
# Extraindo features do arquivo 91 de 480 -> 18.958333333333332%
# Extraindo features do arquivo 92 de 480 -> 19.166666666666668%
# Extraindo features do arquivo 93 de 480 -> 19.375%
# Extraindo features do arquivo 94 de 480 -> 19.583333333333332%
# Extraindo features do arquivo 95 de 480 -> 19.791666666666664%
# Extraindo features do arquivo 96 de 480 -> 20.0%
# Extraindo features do arquivo 97 de 480 -> 20.208333333333332%
# Extraindo features do arquivo 98 de 480 -> 20.416666666666668%
# Extraindo features do arquivo 99 de 480 -> 20.625%
# Extraindo features do arquivo 100 de 480 -> 20.833333333333336%
# Extraindo features do arquivo 101 de 480 -> 21.041666666666668%
# Extraindo features do arquivo 102 de 480 -> 21.25%
# Extraindo features do arquivo 103 de 480 -> 21.458333333333332%
# Extraindo features do arquivo 104 de 480 -> 21.666666666666668%
# Extraindo features do arquivo 105 de 480 -> 21.875%
# Extraindo features do arquivo 106 de 480 -> 22.083333333333332%
# Extraindo features do arquivo 107 de 480 -> 22.291666666666668%
# Extraindo features do arquivo 108 de 480 -> 22.5%
# Extraindo features do arquivo 109 de 480 -> 22.708333333333332%
# Extraindo features do arquivo 110 de 480 -> 22.916666666666664%
# Extraindo features do arquivo 111 de 480 -> 23.125%
# Extraindo features do arquivo 112 de 480 -> 23.333333333333332%
# Extraindo features do arquivo 113 de 480 -> 23.541666666666668%
# Extraindo features do arquivo 114 de 480 -> 23.75%
# Extraindo features do arquivo 115 de 480 -> 23.958333333333336%
# Extraindo features do arquivo 116 de 480 -> 24.166666666666668%
# Extraindo features do arquivo 117 de 480 -> 24.375%
# Extraindo features do arquivo 118 de 480 -> 24.583333333333332%
# Extraindo features do arquivo 119 de 480 -> 24.791666666666668%
# Extraindo features do arquivo 120 de 480 -> 25.0%
# Extraindo features do arquivo 121 de 480 -> 25.208333333333332%
# Extraindo features do arquivo 122 de 480 -> 25.416666666666664%
# Extraindo features do arquivo 123 de 480 -> 25.624999999999996%
# Extraindo features do arquivo 124 de 480 -> 25.833333333333336%
# Extraindo features do arquivo 125 de 480 -> 26.041666666666668%
# Extraindo features do arquivo 126 de 480 -> 26.25%
# Extraindo features do arquivo 127 de 480 -> 26.458333333333332%
# Extraindo features do arquivo 128 de 480 -> 26.666666666666668%
# Extraindo features do arquivo 129 de 480 -> 26.875%
# Extraindo features do arquivo 130 de 480 -> 27.083333333333332%
# Extraindo features do arquivo 131 de 480 -> 27.291666666666664%
# Extraindo features do arquivo 132 de 480 -> 27.500000000000004%
# Extraindo features do arquivo 133 de 480 -> 27.708333333333336%
# Extraindo features do arquivo 134 de 480 -> 27.916666666666668%
# Extraindo features do arquivo 135 de 480 -> 28.125%
# Extraindo features do arquivo 136 de 480 -> 28.333333333333332%
# Extraindo features do arquivo 137 de 480 -> 28.541666666666664%
# Extraindo features do arquivo 138 de 480 -> 28.749999999999996%
# Extraindo features do arquivo 139 de 480 -> 28.958333333333336%
# Extraindo features do arquivo 140 de 480 -> 29.166666666666668%
# Extraindo features do arquivo 141 de 480 -> 29.375%
# Extraindo features do arquivo 142 de 480 -> 29.583333333333332%
# Extraindo features do arquivo 143 de 480 -> 29.791666666666668%
# Extraindo features do arquivo 144 de 480 -> 30.0%
# Extraindo features do arquivo 145 de 480 -> 30.208333333333332%
# Extraindo features do arquivo 146 de 480 -> 30.416666666666664%
# Extraindo features do arquivo 147 de 480 -> 30.625000000000004%
# Extraindo features do arquivo 148 de 480 -> 30.833333333333336%
# Extraindo features do arquivo 149 de 480 -> 31.041666666666668%
# Extraindo features do arquivo 150 de 480 -> 31.25%
# Extraindo features do arquivo 151 de 480 -> 31.458333333333332%
# Extraindo features do arquivo 152 de 480 -> 31.666666666666664%
# Extraindo features do arquivo 153 de 480 -> 31.874999999999996%
# Extraindo features do arquivo 154 de 480 -> 32.083333333333336%
# Extraindo features do arquivo 155 de 480 -> 32.29166666666667%
# Extraindo features do arquivo 156 de 480 -> 32.5%
# Extraindo features do arquivo 157 de 480 -> 32.708333333333336%
# Extraindo features do arquivo 158 de 480 -> 32.916666666666664%
# Extraindo features do arquivo 159 de 480 -> 33.125%
# Extraindo features do arquivo 160 de 480 -> 33.33333333333333%
# Extraindo features do arquivo 161 de 480 -> 33.541666666666664%
# Extraindo features do arquivo 162 de 480 -> 33.75%
# Extraindo features do arquivo 163 de 480 -> 33.958333333333336%
# Extraindo features do arquivo 164 de 480 -> 34.166666666666664%
# Extraindo features do arquivo 165 de 480 -> 34.375%
# Extraindo features do arquivo 166 de 480 -> 34.583333333333336%
# Extraindo features do arquivo 167 de 480 -> 34.791666666666664%
# Extraindo features do arquivo 168 de 480 -> 35.0%
# Extraindo features do arquivo 169 de 480 -> 35.208333333333336%
# Extraindo features do arquivo 170 de 480 -> 35.41666666666667%
# Extraindo features do arquivo 171 de 480 -> 35.625%
# Extraindo features do arquivo 172 de 480 -> 35.833333333333336%
# Extraindo features do arquivo 173 de 480 -> 36.041666666666664%
# Extraindo features do arquivo 174 de 480 -> 36.25%
# Extraindo features do arquivo 175 de 480 -> 36.45833333333333%
# Extraindo features do arquivo 176 de 480 -> 36.666666666666664%
# Extraindo features do arquivo 177 de 480 -> 36.875%
# Extraindo features do arquivo 178 de 480 -> 37.083333333333336%
# Extraindo features do arquivo 179 de 480 -> 37.291666666666664%
# Extraindo features do arquivo 180 de 480 -> 37.5%
# Extraindo features do arquivo 181 de 480 -> 37.708333333333336%
# Extraindo features do arquivo 182 de 480 -> 37.916666666666664%
# Extraindo features do arquivo 183 de 480 -> 38.125%
# Extraindo features do arquivo 184 de 480 -> 38.333333333333336%
# Extraindo features do arquivo 185 de 480 -> 38.54166666666667%
# Extraindo features do arquivo 186 de 480 -> 38.75%
# Extraindo features do arquivo 187 de 480 -> 38.958333333333336%
# Extraindo features do arquivo 188 de 480 -> 39.166666666666664%
# Extraindo features do arquivo 189 de 480 -> 39.375%
# Extraindo features do arquivo 190 de 480 -> 39.58333333333333%
# Extraindo features do arquivo 191 de 480 -> 39.791666666666664%
# Extraindo features do arquivo 192 de 480 -> 40.0%
# Extraindo features do arquivo 193 de 480 -> 40.208333333333336%
# Extraindo features do arquivo 194 de 480 -> 40.416666666666664%
# Extraindo features do arquivo 195 de 480 -> 40.625%
# Extraindo features do arquivo 196 de 480 -> 40.833333333333336%
# Extraindo features do arquivo 197 de 480 -> 41.041666666666664%
# Extraindo features do arquivo 198 de 480 -> 41.25%
# Extraindo features do arquivo 199 de 480 -> 41.458333333333336%
# Extraindo features do arquivo 200 de 480 -> 41.66666666666667%
# Extraindo features do arquivo 201 de 480 -> 41.875%
# Extraindo features do arquivo 202 de 480 -> 42.083333333333336%
# Extraindo features do arquivo 203 de 480 -> 42.291666666666664%
# Extraindo features do arquivo 204 de 480 -> 42.5%
# Extraindo features do arquivo 205 de 480 -> 42.70833333333333%
# Extraindo features do arquivo 206 de 480 -> 42.916666666666664%
# Extraindo features do arquivo 207 de 480 -> 43.125%
# Extraindo features do arquivo 208 de 480 -> 43.333333333333336%
# Extraindo features do arquivo 209 de 480 -> 43.541666666666664%
# Extraindo features do arquivo 210 de 480 -> 43.75%
# Extraindo features do arquivo 211 de 480 -> 43.958333333333336%
# Extraindo features do arquivo 212 de 480 -> 44.166666666666664%
# Extraindo features do arquivo 213 de 480 -> 44.375%
# Extraindo features do arquivo 214 de 480 -> 44.583333333333336%
# Extraindo features do arquivo 215 de 480 -> 44.79166666666667%
# Extraindo features do arquivo 216 de 480 -> 45.0%
# Extraindo features do arquivo 217 de 480 -> 45.208333333333336%
# Extraindo features do arquivo 218 de 480 -> 45.416666666666664%
# Extraindo features do arquivo 219 de 480 -> 45.625%
# Extraindo features do arquivo 220 de 480 -> 45.83333333333333%
# Extraindo features do arquivo 221 de 480 -> 46.041666666666664%
# Extraindo features do arquivo 222 de 480 -> 46.25%
# Extraindo features do arquivo 223 de 480 -> 46.458333333333336%
# Extraindo features do arquivo 224 de 480 -> 46.666666666666664%
# Extraindo features do arquivo 225 de 480 -> 46.875%
# Extraindo features do arquivo 226 de 480 -> 47.083333333333336%
# Extraindo features do arquivo 227 de 480 -> 47.291666666666664%
# Extraindo features do arquivo 228 de 480 -> 47.5%
# Extraindo features do arquivo 229 de 480 -> 47.708333333333336%
# Extraindo features do arquivo 230 de 480 -> 47.91666666666667%
# Extraindo features do arquivo 231 de 480 -> 48.125%
# Extraindo features do arquivo 232 de 480 -> 48.333333333333336%
# Extraindo features do arquivo 233 de 480 -> 48.541666666666664%
# Extraindo features do arquivo 234 de 480 -> 48.75%
# Extraindo features do arquivo 235 de 480 -> 48.95833333333333%
# Extraindo features do arquivo 236 de 480 -> 49.166666666666664%
# Extraindo features do arquivo 237 de 480 -> 49.375%
# Extraindo features do arquivo 238 de 480 -> 49.583333333333336%
# Extraindo features do arquivo 239 de 480 -> 49.791666666666664%
# Extraindo features do arquivo 240 de 480 -> 50.0%
# Extraindo features do arquivo 241 de 480 -> 50.208333333333336%
# Extraindo features do arquivo 242 de 480 -> 50.416666666666664%
# Extraindo features do arquivo 243 de 480 -> 50.625%
# Extraindo features do arquivo 244 de 480 -> 50.83333333333333%
# Extraindo features do arquivo 245 de 480 -> 51.041666666666664%
# Extraindo features do arquivo 246 de 480 -> 51.24999999999999%
# Extraindo features do arquivo 247 de 480 -> 51.45833333333333%
# Extraindo features do arquivo 248 de 480 -> 51.66666666666667%
# Extraindo features do arquivo 249 de 480 -> 51.87500000000001%
# Extraindo features do arquivo 250 de 480 -> 52.083333333333336%
# Extraindo features do arquivo 251 de 480 -> 52.29166666666667%
# Extraindo features do arquivo 252 de 480 -> 52.5%
# Extraindo features do arquivo 253 de 480 -> 52.708333333333336%
# Extraindo features do arquivo 254 de 480 -> 52.916666666666664%
# Extraindo features do arquivo 255 de 480 -> 53.125%
# Extraindo features do arquivo 256 de 480 -> 53.333333333333336%
# Extraindo features do arquivo 257 de 480 -> 53.541666666666664%
# Extraindo features do arquivo 258 de 480 -> 53.75%
# Extraindo features do arquivo 259 de 480 -> 53.95833333333333%
# Extraindo features do arquivo 260 de 480 -> 54.166666666666664%
# Extraindo features do arquivo 261 de 480 -> 54.37499999999999%
# Extraindo features do arquivo 262 de 480 -> 54.58333333333333%
# Extraindo features do arquivo 263 de 480 -> 54.79166666666667%
# Extraindo features do arquivo 264 de 480 -> 55.00000000000001%
# Extraindo features do arquivo 265 de 480 -> 55.208333333333336%
# Extraindo features do arquivo 266 de 480 -> 55.41666666666667%
# Extraindo features do arquivo 267 de 480 -> 55.625%
# Extraindo features do arquivo 268 de 480 -> 55.833333333333336%
# Extraindo features do arquivo 269 de 480 -> 56.041666666666664%
# Extraindo features do arquivo 270 de 480 -> 56.25%
# Extraindo features do arquivo 271 de 480 -> 56.458333333333336%
# Extraindo features do arquivo 272 de 480 -> 56.666666666666664%
# Extraindo features do arquivo 273 de 480 -> 56.875%
# Extraindo features do arquivo 274 de 480 -> 57.08333333333333%
# Extraindo features do arquivo 275 de 480 -> 57.291666666666664%
# Extraindo features do arquivo 276 de 480 -> 57.49999999999999%
# Extraindo features do arquivo 277 de 480 -> 57.70833333333333%
# Extraindo features do arquivo 278 de 480 -> 57.91666666666667%
# Extraindo features do arquivo 279 de 480 -> 58.12500000000001%
# Extraindo features do arquivo 280 de 480 -> 58.333333333333336%
# Extraindo features do arquivo 281 de 480 -> 58.54166666666667%
# Extraindo features do arquivo 282 de 480 -> 58.75%
# Extraindo features do arquivo 283 de 480 -> 58.958333333333336%
# Extraindo features do arquivo 284 de 480 -> 59.166666666666664%
# Extraindo features do arquivo 285 de 480 -> 59.375%
# Extraindo features do arquivo 286 de 480 -> 59.583333333333336%
# Extraindo features do arquivo 287 de 480 -> 59.791666666666664%
# Extraindo features do arquivo 288 de 480 -> 60.0%
# Extraindo features do arquivo 289 de 480 -> 60.20833333333333%
# Extraindo features do arquivo 290 de 480 -> 60.416666666666664%
# Extraindo features do arquivo 291 de 480 -> 60.62499999999999%
# Extraindo features do arquivo 292 de 480 -> 60.83333333333333%
# Extraindo features do arquivo 293 de 480 -> 61.04166666666667%
# Extraindo features do arquivo 294 de 480 -> 61.25000000000001%
# Extraindo features do arquivo 295 de 480 -> 61.458333333333336%
# Extraindo features do arquivo 296 de 480 -> 61.66666666666667%
# Extraindo features do arquivo 297 de 480 -> 61.875%
# Extraindo features do arquivo 298 de 480 -> 62.083333333333336%
# Extraindo features do arquivo 299 de 480 -> 62.291666666666664%
# Extraindo features do arquivo 300 de 480 -> 62.5%
# Extraindo features do arquivo 301 de 480 -> 62.708333333333336%
# Extraindo features do arquivo 302 de 480 -> 62.916666666666664%
# Extraindo features do arquivo 303 de 480 -> 63.125%
# Extraindo features do arquivo 304 de 480 -> 63.33333333333333%
# Extraindo features do arquivo 305 de 480 -> 63.541666666666664%
# Extraindo features do arquivo 306 de 480 -> 63.74999999999999%
# Extraindo features do arquivo 307 de 480 -> 63.95833333333333%
# Extraindo features do arquivo 308 de 480 -> 64.16666666666667%
# Extraindo features do arquivo 309 de 480 -> 64.375%
# Extraindo features do arquivo 310 de 480 -> 64.58333333333334%
# Extraindo features do arquivo 311 de 480 -> 64.79166666666667%
# Extraindo features do arquivo 312 de 480 -> 65.0%
# Extraindo features do arquivo 313 de 480 -> 65.20833333333333%
# Extraindo features do arquivo 314 de 480 -> 65.41666666666667%
# Extraindo features do arquivo 315 de 480 -> 65.625%
# Extraindo features do arquivo 316 de 480 -> 65.83333333333333%
# Extraindo features do arquivo 317 de 480 -> 66.04166666666667%
# Extraindo features do arquivo 318 de 480 -> 66.25%
# Extraindo features do arquivo 319 de 480 -> 66.45833333333333%
# Extraindo features do arquivo 320 de 480 -> 66.66666666666666%
# Extraindo features do arquivo 321 de 480 -> 66.875%
# Extraindo features do arquivo 322 de 480 -> 67.08333333333333%
# Extraindo features do arquivo 323 de 480 -> 67.29166666666667%
# Extraindo features do arquivo 324 de 480 -> 67.5%
# Extraindo features do arquivo 325 de 480 -> 67.70833333333334%
# Extraindo features do arquivo 326 de 480 -> 67.91666666666667%
# Extraindo features do arquivo 327 de 480 -> 68.125%
# Extraindo features do arquivo 328 de 480 -> 68.33333333333333%
# Extraindo features do arquivo 329 de 480 -> 68.54166666666667%
# Extraindo features do arquivo 330 de 480 -> 68.75%
# Extraindo features do arquivo 331 de 480 -> 68.95833333333333%
# Extraindo features do arquivo 332 de 480 -> 69.16666666666667%
# Extraindo features do arquivo 333 de 480 -> 69.375%
# Extraindo features do arquivo 334 de 480 -> 69.58333333333333%
# Extraindo features do arquivo 335 de 480 -> 69.79166666666666%
# Extraindo features do arquivo 336 de 480 -> 70.0%
# Extraindo features do arquivo 337 de 480 -> 70.20833333333333%
# Extraindo features do arquivo 338 de 480 -> 70.41666666666667%
# Extraindo features do arquivo 339 de 480 -> 70.625%
# Extraindo features do arquivo 340 de 480 -> 70.83333333333334%
# Extraindo features do arquivo 341 de 480 -> 71.04166666666667%
# Extraindo features do arquivo 342 de 480 -> 71.25%
# Extraindo features do arquivo 343 de 480 -> 71.45833333333333%
# Extraindo features do arquivo 344 de 480 -> 71.66666666666667%
# Extraindo features do arquivo 345 de 480 -> 71.875%
# Extraindo features do arquivo 346 de 480 -> 72.08333333333333%
# Extraindo features do arquivo 347 de 480 -> 72.29166666666667%
# Extraindo features do arquivo 348 de 480 -> 72.5%
# Extraindo features do arquivo 349 de 480 -> 72.70833333333333%
# Extraindo features do arquivo 350 de 480 -> 72.91666666666666%
# Extraindo features do arquivo 351 de 480 -> 73.125%
# Extraindo features do arquivo 352 de 480 -> 73.33333333333333%
# Extraindo features do arquivo 353 de 480 -> 73.54166666666667%
# Extraindo features do arquivo 354 de 480 -> 73.75%
# Extraindo features do arquivo 355 de 480 -> 73.95833333333334%
# Extraindo features do arquivo 356 de 480 -> 74.16666666666667%
# Extraindo features do arquivo 357 de 480 -> 74.375%
# Extraindo features do arquivo 358 de 480 -> 74.58333333333333%
# Extraindo features do arquivo 359 de 480 -> 74.79166666666667%
# Extraindo features do arquivo 360 de 480 -> 75.0%
# Extraindo features do arquivo 361 de 480 -> 75.20833333333333%
# Extraindo features do arquivo 362 de 480 -> 75.41666666666667%
# Extraindo features do arquivo 363 de 480 -> 75.625%
# Extraindo features do arquivo 364 de 480 -> 75.83333333333333%
# Extraindo features do arquivo 365 de 480 -> 76.04166666666666%
# Extraindo features do arquivo 366 de 480 -> 76.25%
# Extraindo features do arquivo 367 de 480 -> 76.45833333333333%
# Extraindo features do arquivo 368 de 480 -> 76.66666666666667%
# Extraindo features do arquivo 369 de 480 -> 76.875%
# Extraindo features do arquivo 370 de 480 -> 77.08333333333334%
# Extraindo features do arquivo 371 de 480 -> 77.29166666666667%
# Extraindo features do arquivo 372 de 480 -> 77.5%
# Extraindo features do arquivo 373 de 480 -> 77.70833333333333%
# Extraindo features do arquivo 374 de 480 -> 77.91666666666667%
# Extraindo features do arquivo 375 de 480 -> 78.125%
# Extraindo features do arquivo 376 de 480 -> 78.33333333333333%
# Extraindo features do arquivo 377 de 480 -> 78.54166666666667%
# Extraindo features do arquivo 378 de 480 -> 78.75%
# Extraindo features do arquivo 379 de 480 -> 78.95833333333333%
# Extraindo features do arquivo 380 de 480 -> 79.16666666666666%
# Extraindo features do arquivo 381 de 480 -> 79.375%
# Extraindo features do arquivo 382 de 480 -> 79.58333333333333%
# Extraindo features do arquivo 383 de 480 -> 79.79166666666667%
# Extraindo features do arquivo 384 de 480 -> 80.0%
# Extraindo features do arquivo 385 de 480 -> 80.20833333333334%
# Extraindo features do arquivo 386 de 480 -> 80.41666666666667%
# Extraindo features do arquivo 387 de 480 -> 80.625%
# Extraindo features do arquivo 388 de 480 -> 80.83333333333333%
# Extraindo features do arquivo 389 de 480 -> 81.04166666666667%
# Extraindo features do arquivo 390 de 480 -> 81.25%
# Extraindo features do arquivo 391 de 480 -> 81.45833333333333%
# Extraindo features do arquivo 392 de 480 -> 81.66666666666667%
# Extraindo features do arquivo 393 de 480 -> 81.875%
# Extraindo features do arquivo 394 de 480 -> 82.08333333333333%
# Extraindo features do arquivo 395 de 480 -> 82.29166666666666%
# Extraindo features do arquivo 396 de 480 -> 82.5%
# Extraindo features do arquivo 397 de 480 -> 82.70833333333333%
# Extraindo features do arquivo 398 de 480 -> 82.91666666666667%
# Extraindo features do arquivo 399 de 480 -> 83.125%
# Extraindo features do arquivo 400 de 480 -> 83.33333333333334%
# Extraindo features do arquivo 401 de 480 -> 83.54166666666667%
# Extraindo features do arquivo 402 de 480 -> 83.75%
# Extraindo features do arquivo 403 de 480 -> 83.95833333333333%
# Extraindo features do arquivo 404 de 480 -> 84.16666666666667%
# Extraindo features do arquivo 405 de 480 -> 84.375%
# Extraindo features do arquivo 406 de 480 -> 84.58333333333333%
# Extraindo features do arquivo 407 de 480 -> 84.79166666666667%
# Extraindo features do arquivo 408 de 480 -> 85.0%
# Extraindo features do arquivo 409 de 480 -> 85.20833333333333%
# Extraindo features do arquivo 410 de 480 -> 85.41666666666666%
# Extraindo features do arquivo 411 de 480 -> 85.625%
# Extraindo features do arquivo 412 de 480 -> 85.83333333333333%
# Extraindo features do arquivo 413 de 480 -> 86.04166666666667%
# Extraindo features do arquivo 414 de 480 -> 86.25%
# Extraindo features do arquivo 415 de 480 -> 86.45833333333334%
# Extraindo features do arquivo 416 de 480 -> 86.66666666666667%
# Extraindo features do arquivo 417 de 480 -> 86.875%
# Extraindo features do arquivo 418 de 480 -> 87.08333333333333%
# Extraindo features do arquivo 419 de 480 -> 87.29166666666667%
# Extraindo features do arquivo 420 de 480 -> 87.5%
# Extraindo features do arquivo 421 de 480 -> 87.70833333333333%
# Extraindo features do arquivo 422 de 480 -> 87.91666666666667%
# Extraindo features do arquivo 423 de 480 -> 88.125%
# Extraindo features do arquivo 424 de 480 -> 88.33333333333333%
# Extraindo features do arquivo 425 de 480 -> 88.54166666666666%
# Extraindo features do arquivo 426 de 480 -> 88.75%
# Extraindo features do arquivo 427 de 480 -> 88.95833333333333%
# Extraindo features do arquivo 428 de 480 -> 89.16666666666667%
# Extraindo features do arquivo 429 de 480 -> 89.375%
# Extraindo features do arquivo 430 de 480 -> 89.58333333333334%
# Extraindo features do arquivo 431 de 480 -> 89.79166666666667%
# Extraindo features do arquivo 432 de 480 -> 90.0%
# Extraindo features do arquivo 433 de 480 -> 90.20833333333333%
# Extraindo features do arquivo 434 de 480 -> 90.41666666666667%
# Extraindo features do arquivo 435 de 480 -> 90.625%
# Extraindo features do arquivo 436 de 480 -> 90.83333333333333%
# Extraindo features do arquivo 437 de 480 -> 91.04166666666667%
# Extraindo features do arquivo 438 de 480 -> 91.25%
# Extraindo features do arquivo 439 de 480 -> 91.45833333333333%
# Extraindo features do arquivo 440 de 480 -> 91.66666666666666%
# Extraindo features do arquivo 441 de 480 -> 91.875%
# Extraindo features do arquivo 442 de 480 -> 92.08333333333333%
# Extraindo features do arquivo 443 de 480 -> 92.29166666666667%
# Extraindo features do arquivo 444 de 480 -> 92.5%
# Extraindo features do arquivo 445 de 480 -> 92.70833333333334%
# Extraindo features do arquivo 446 de 480 -> 92.91666666666667%
# Extraindo features do arquivo 447 de 480 -> 93.125%
# Extraindo features do arquivo 448 de 480 -> 93.33333333333333%
# Extraindo features do arquivo 449 de 480 -> 93.54166666666667%
# Extraindo features do arquivo 450 de 480 -> 93.75%
# Extraindo features do arquivo 451 de 480 -> 93.95833333333333%
# Extraindo features do arquivo 452 de 480 -> 94.16666666666667%
# Extraindo features do arquivo 453 de 480 -> 94.375%
# Extraindo features do arquivo 454 de 480 -> 94.58333333333333%
# Extraindo features do arquivo 455 de 480 -> 94.79166666666666%
# Extraindo features do arquivo 456 de 480 -> 95.0%
# Extraindo features do arquivo 457 de 480 -> 95.20833333333333%
# Extraindo features do arquivo 458 de 480 -> 95.41666666666667%
# Extraindo features do arquivo 459 de 480 -> 95.625%
# Extraindo features do arquivo 460 de 480 -> 95.83333333333334%
# Extraindo features do arquivo 461 de 480 -> 96.04166666666667%
# Extraindo features do arquivo 462 de 480 -> 96.25%
# Extraindo features do arquivo 463 de 480 -> 96.45833333333333%
# Extraindo features do arquivo 464 de 480 -> 96.66666666666667%
# Extraindo features do arquivo 465 de 480 -> 96.875%
# Extraindo features do arquivo 466 de 480 -> 97.08333333333333%
# Extraindo features do arquivo 467 de 480 -> 97.29166666666667%
# Extraindo features do arquivo 468 de 480 -> 97.5%
# Extraindo features do arquivo 469 de 480 -> 97.70833333333333%
# Extraindo features do arquivo 470 de 480 -> 97.91666666666666%
# Extraindo features do arquivo 471 de 480 -> 98.125%
# Extraindo features do arquivo 472 de 480 -> 98.33333333333333%
# Extraindo features do arquivo 473 de 480 -> 98.54166666666667%
# Extraindo features do arquivo 474 de 480 -> 98.75%
# Extraindo features do arquivo 475 de 480 -> 98.95833333333334%
# Extraindo features do arquivo 476 de 480 -> 99.16666666666667%
# Extraindo features do arquivo 477 de 480 -> 99.375%
# Extraindo features do arquivo 478 de 480 -> 99.58333333333333%
# Extraindo features do arquivo 479 de 480 -> 99.79166666666667%
# Extraindo features do arquivo 480 de 480 -> 100.0%
# Escalonando features
# Reduzindo a dimensionalidade
# Escrevendo CSV: /home/dimi/Downloads/SESA/train/1580365150.2439735.csv
# Operação finalizada

# %%
diretorio      = "/home/dimi/Downloads/SESA/test/"
freqAmostragem = 16000
frameLength    = 17145
overlapLength  = 8572
escalonamento  = True
nDimensoes     = 53

ExtrairFeatures(diretorio, freqAmostragem, frameLength, overlapLength, escalonamento, nDimensoes)
# Out:
# Extraindo features do arquivo 1 de 105 -> 0.9523809523809524%
# Extraindo features do arquivo 2 de 105 -> 1.9047619047619049%
# Extraindo features do arquivo 3 de 105 -> 2.857142857142857%
# Extraindo features do arquivo 4 de 105 -> 3.8095238095238098%
# Extraindo features do arquivo 5 de 105 -> 4.761904761904762%
# Extraindo features do arquivo 6 de 105 -> 5.714285714285714%
# Extraindo features do arquivo 7 de 105 -> 6.666666666666667%
# Extraindo features do arquivo 8 de 105 -> 7.6190476190476195%
# Extraindo features do arquivo 9 de 105 -> 8.571428571428571%
# Extraindo features do arquivo 10 de 105 -> 9.523809523809524%
# Extraindo features do arquivo 11 de 105 -> 10.476190476190476%
# Extraindo features do arquivo 12 de 105 -> 11.428571428571429%
# Extraindo features do arquivo 13 de 105 -> 12.380952380952381%
# Extraindo features do arquivo 14 de 105 -> 13.333333333333334%
# Extraindo features do arquivo 15 de 105 -> 14.285714285714285%
# Extraindo features do arquivo 16 de 105 -> 15.238095238095239%
# Extraindo features do arquivo 17 de 105 -> 16.19047619047619%
# Extraindo features do arquivo 18 de 105 -> 17.142857142857142%
# Extraindo features do arquivo 19 de 105 -> 18.095238095238095%
# Extraindo features do arquivo 20 de 105 -> 19.047619047619047%
# Extraindo features do arquivo 21 de 105 -> 20.0%
# Extraindo features do arquivo 22 de 105 -> 20.952380952380953%
# Extraindo features do arquivo 23 de 105 -> 21.904761904761905%
# Extraindo features do arquivo 24 de 105 -> 22.857142857142858%
# Extraindo features do arquivo 25 de 105 -> 23.809523809523807%
# Extraindo features do arquivo 26 de 105 -> 24.761904761904763%
# Extraindo features do arquivo 27 de 105 -> 25.71428571428571%
# Extraindo features do arquivo 28 de 105 -> 26.666666666666668%
# Extraindo features do arquivo 29 de 105 -> 27.61904761904762%
# Extraindo features do arquivo 30 de 105 -> 28.57142857142857%
# Extraindo features do arquivo 31 de 105 -> 29.523809523809526%
# Extraindo features do arquivo 32 de 105 -> 30.476190476190478%
# Extraindo features do arquivo 33 de 105 -> 31.428571428571427%
# Extraindo features do arquivo 34 de 105 -> 32.38095238095238%
# Extraindo features do arquivo 35 de 105 -> 33.33333333333333%
# Extraindo features do arquivo 36 de 105 -> 34.285714285714285%
# Extraindo features do arquivo 37 de 105 -> 35.23809523809524%
# Extraindo features do arquivo 38 de 105 -> 36.19047619047619%
# Extraindo features do arquivo 39 de 105 -> 37.142857142857146%
# Extraindo features do arquivo 40 de 105 -> 38.095238095238095%
# Extraindo features do arquivo 41 de 105 -> 39.04761904761905%
# Extraindo features do arquivo 42 de 105 -> 40.0%
# Extraindo features do arquivo 43 de 105 -> 40.95238095238095%
# Extraindo features do arquivo 44 de 105 -> 41.904761904761905%
# Extraindo features do arquivo 45 de 105 -> 42.857142857142854%
# Extraindo features do arquivo 46 de 105 -> 43.80952380952381%
# Extraindo features do arquivo 47 de 105 -> 44.761904761904766%
# Extraindo features do arquivo 48 de 105 -> 45.714285714285715%
# Extraindo features do arquivo 49 de 105 -> 46.666666666666664%
# Extraindo features do arquivo 50 de 105 -> 47.61904761904761%
# Extraindo features do arquivo 51 de 105 -> 48.57142857142857%
# Extraindo features do arquivo 52 de 105 -> 49.523809523809526%
# Extraindo features do arquivo 53 de 105 -> 50.476190476190474%
# Extraindo features do arquivo 54 de 105 -> 51.42857142857142%
# Extraindo features do arquivo 55 de 105 -> 52.38095238095239%
# Extraindo features do arquivo 56 de 105 -> 53.333333333333336%
# Extraindo features do arquivo 57 de 105 -> 54.285714285714285%
# Extraindo features do arquivo 58 de 105 -> 55.23809523809524%
# Extraindo features do arquivo 59 de 105 -> 56.19047619047619%
# Extraindo features do arquivo 60 de 105 -> 57.14285714285714%
# Extraindo features do arquivo 61 de 105 -> 58.0952380952381%
# Extraindo features do arquivo 62 de 105 -> 59.04761904761905%
# Extraindo features do arquivo 63 de 105 -> 60.0%
# Extraindo features do arquivo 64 de 105 -> 60.952380952380956%
# Extraindo features do arquivo 65 de 105 -> 61.904761904761905%
# Extraindo features do arquivo 66 de 105 -> 62.857142857142854%
# Extraindo features do arquivo 67 de 105 -> 63.8095238095238%
# Extraindo features do arquivo 68 de 105 -> 64.76190476190476%
# Extraindo features do arquivo 69 de 105 -> 65.71428571428571%
# Extraindo features do arquivo 70 de 105 -> 66.66666666666666%
# Extraindo features do arquivo 71 de 105 -> 67.61904761904762%
# Extraindo features do arquivo 72 de 105 -> 68.57142857142857%
# Extraindo features do arquivo 73 de 105 -> 69.52380952380952%
# Extraindo features do arquivo 74 de 105 -> 70.47619047619048%
# Extraindo features do arquivo 75 de 105 -> 71.42857142857143%
# Extraindo features do arquivo 76 de 105 -> 72.38095238095238%
# Extraindo features do arquivo 77 de 105 -> 73.33333333333333%
# Extraindo features do arquivo 78 de 105 -> 74.28571428571429%
# Extraindo features do arquivo 79 de 105 -> 75.23809523809524%
# Extraindo features do arquivo 80 de 105 -> 76.19047619047619%
# Extraindo features do arquivo 81 de 105 -> 77.14285714285715%
# Extraindo features do arquivo 82 de 105 -> 78.0952380952381%
# Extraindo features do arquivo 83 de 105 -> 79.04761904761905%
# Extraindo features do arquivo 84 de 105 -> 80.0%
# Extraindo features do arquivo 85 de 105 -> 80.95238095238095%
# Extraindo features do arquivo 86 de 105 -> 81.9047619047619%
# Extraindo features do arquivo 87 de 105 -> 82.85714285714286%
# Extraindo features do arquivo 88 de 105 -> 83.80952380952381%
# Extraindo features do arquivo 89 de 105 -> 84.76190476190476%
# Extraindo features do arquivo 90 de 105 -> 85.71428571428571%
# Extraindo features do arquivo 91 de 105 -> 86.66666666666667%
# Extraindo features do arquivo 92 de 105 -> 87.61904761904762%
# Extraindo features do arquivo 93 de 105 -> 88.57142857142857%
# Extraindo features do arquivo 94 de 105 -> 89.52380952380953%
# Extraindo features do arquivo 95 de 105 -> 90.47619047619048%
# Extraindo features do arquivo 96 de 105 -> 91.42857142857143%
# Extraindo features do arquivo 97 de 105 -> 92.38095238095238%
# Extraindo features do arquivo 98 de 105 -> 93.33333333333333%
# Extraindo features do arquivo 99 de 105 -> 94.28571428571428%
# Extraindo features do arquivo 100 de 105 -> 95.23809523809523%
# Extraindo features do arquivo 101 de 105 -> 96.19047619047619%
# Extraindo features do arquivo 102 de 105 -> 97.14285714285714%
# Extraindo features do arquivo 103 de 105 -> 98.09523809523809%
# Extraindo features do arquivo 104 de 105 -> 99.04761904761905%
# Extraindo features do arquivo 105 de 105 -> 100.0%
# Escalonando features
# Reduzindo a dimensionalidade
# Escrevendo CSV: /home/dimi/Downloads/SESA/test/1580365515.8369567.csv
# Operação finalizada
