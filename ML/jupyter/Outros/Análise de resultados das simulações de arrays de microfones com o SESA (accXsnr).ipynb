# %% [markdown]
# # Análise dos resultados das simulações de arrays de microfones com o SESA

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## ACESSANDO OS DADOS

# %% [markdown]
# Os resultados serão organizados no dicionário a seguir que segue a estrutura:
#
# **1ª dimensão:** SNR
#
# **2ª dimensão:** Classificador
#
# **3ª dimensão:** Tipo de Beamforming
#
# **4ª dimensão:** Array com acurácias

# %%
dicionarioDados = {
	"SNR_-10dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},    
	"SNR_-9dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-8dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-7dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-6dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-5dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-4dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-3dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-2dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-1dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_0dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_1dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_2dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_3dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_4dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_5dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_6dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_7dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_8dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_9dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_10dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_11dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_12dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_13dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_14dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_15dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_16dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_17dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_18dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_19dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_20dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_21dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_22dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_23dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_24dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_25dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_26dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_27dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_28dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_29dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_30dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	}
}

# %% [markdown]
# ## Começando

# %%
rangeSNRs = list(np.arange(-10, 31, 1))

# %%
# ORIGEM DE ONDE VAO ESTAR AS PASTAS COM OS SNRS CHEIOS DE RELATORIOS DE CLASSIFICADORES
diretorioOrigem  = "/home/dimi/Programming/IC2019/ML/relatorios_classificacao/SESA_Normalizado/graficosACCxSNR/RBRANCO_DIFUSO/original_dataset/com_gridsearch/"

# PARA CADA PASTA DE SNR
for SNRAtual in rangeSNRs:
    
    # PEGANDO OS NOMES DE TODOS OS JSONS DENTRO DESSA PASTA DE SNR ATUAL
    diretorioSNRAtual = diretorioOrigem + "SNR_" + str(SNRAtual) + "dB/"
    arrayArquivosJSONSNRAtual = [arquivo for arquivo in os.listdir(diretorioSNRAtual) if arquivo.endswith(".json")]
    
    # PARA CADA JSON
    for nomeJSONAtual in arrayArquivosJSONSNRAtual:
        
        # EU ABRO O JSON
        with open(diretorioSNRAtual + nomeJSONAtual) as arquivoJSON:
            dadosJSON = json.load(arquivoJSON)

            # PEGO A ACURACIA ATUAL
            acuraciaAtual = dadosJSON["accuracy"]

            # VERIFICO ONDE EU TENHO QUE COLOCAR NO DICIONARIO
            keySNR         = "SNR_" + str(SNRAtual) + "dB"
            classificador  = dadosJSON["classificador"]
            tipoBeamfoming = nomeJSONAtual.split("_")[2]
            
            # E COLOCO NO LUGAR CERTO 
            dicionarioDados[keySNR][classificador][tipoBeamfoming].append(acuraciaAtual)

# %% [markdown]
# ## Analisando os resultados

# %%
#DEFININDO ALGUNS PARÂMETROS DO GRÁFICO
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
params = {'figure.figsize': [12, 6.5], 
          'axes.labelsize': 20,
          'axes.titlesize':22, 
          'font.size': 20,
          'legend.fontsize': 20, 
          'xtick.labelsize': 20, 
          'ytick.labelsize': 20,
          'axes.axisbelow': True
         }

plt.rcParams.update(params)

# %% [markdown]
# ### KNN

# %%
classificador = "KNeighborsClassifier"

mediaAcuraciasSemBeamformingKNN = []
mediaAcuraciasComBeamformingKNN = []
mediaAcuraciasComGSCKNN         = []
desvPadSemBeamformingKNN        = []
desvPadComBeamformingKNN        = []
desvPadComGSCKNN                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingKNN.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingKNN.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCKNN.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingKNN.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingKNN.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCKNN.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingKNN, fmt="--", linewidth=1, yerr=desvPadSemBeamformingKNN, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingKNN, fmt="--", linewidth=1, yerr=desvPadComBeamformingKNN, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCKNN, fmt="--", linewidth=1, yerr=desvPadComGSCKNN, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "SGDClassifier"

mediaAcuraciasSemBeamformingSGD = []
mediaAcuraciasComBeamformingSGD = []
mediaAcuraciasComGSCSGD         = []
desvPadSemBeamformingSGD        = []
desvPadComBeamformingSGD        = []
desvPadComGSCSGD                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingSGD.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingSGD.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCSGD.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingSGD.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingSGD.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCSGD.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingSGD, fmt="--", linewidth=1, yerr=desvPadSemBeamformingSGD, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingSGD, fmt="--", linewidth=1, yerr=desvPadComBeamformingSGD, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCSGD, fmt="--", linewidth=1, yerr=desvPadComGSCSGD, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "Perceptron"

mediaAcuraciasSemBeamformingPerceptron = []
mediaAcuraciasComBeamformingPerceptron = []
mediaAcuraciasComGSCPerceptron         = []
desvPadSemBeamformingPerceptron        = []
desvPadComBeamformingPerceptron        = []
desvPadComGSCPerceptron                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingPerceptron.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingPerceptron.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCPerceptron.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingPerceptron.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingPerceptron.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCPerceptron.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingPerceptron, fmt="--", linewidth=1, yerr=desvPadSemBeamformingPerceptron, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingPerceptron, fmt="--", linewidth=1, yerr=desvPadComBeamformingPerceptron, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCPerceptron, fmt="--", linewidth=1, yerr=desvPadComGSCPerceptron, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "SVC"

mediaAcuraciasSemBeamformingSVM = []
mediaAcuraciasComBeamformingSVM = []
mediaAcuraciasComGSCSVM         = []
desvPadSemBeamformingSVM        = []
desvPadComBeamformingSVM        = []
desvPadComGSCSVM                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingSVM.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingSVM.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCSVM.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingSVM.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingSVM.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCSVM.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
#plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingSVM, fmt="--", linewidth=2, yerr=desvPadSemBeamformingSVM, elinewidth=2, capsize=3, label="No Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingSVM, fmt="--", linewidth=2, yerr=desvPadComBeamformingSVM, elinewidth=2, capsize=3, label="Delay and Sum")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCSVM, fmt="--", linewidth=2, yerr=desvPadComGSCSVM, elinewidth=2, capsize=3, label="GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Accuracy")

plt.grid(alpha=0.5)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "LinearDiscriminantAnalysis"

mediaAcuraciasSemBeamformingLDA = []
mediaAcuraciasComBeamformingLDA = []
mediaAcuraciasComGSCLDA         = []
desvPadSemBeamformingLDA        = []
desvPadComBeamformingLDA        = []
desvPadComGSCLDA                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingLDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingLDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCLDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingLDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingLDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCLDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingLDA, fmt="--", linewidth=1, yerr=desvPadSemBeamformingLDA, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingLDA, fmt="--", linewidth=1, yerr=desvPadComBeamformingLDA, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCLDA, fmt="--", linewidth=1, yerr=desvPadComGSCLDA, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "DecisionTreeClassifier"

mediaAcuraciasSemBeamformingTree = []
mediaAcuraciasComBeamformingTree = []
mediaAcuraciasComGSCTree         = []
desvPadSemBeamformingTree        = []
desvPadComBeamformingTree        = []
desvPadComGSCTree                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingTree.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingTree.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCTree.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingTree.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingTree.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCTree.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingTree, fmt="--", linewidth=1, yerr=desvPadSemBeamformingTree, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingTree, fmt="--", linewidth=1, yerr=desvPadComBeamformingTree, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCTree, fmt="--", linewidth=1, yerr=desvPadComGSCTree, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "QuadraticDiscriminantAnalysis"

mediaAcuraciasSemBeamformingQDA = []
mediaAcuraciasComBeamformingQDA = []
mediaAcuraciasComGSCQDA         = []
desvPadSemBeamformingQDA        = []
desvPadComBeamformingQDA        = []
desvPadComGSCQDA                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingQDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingQDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCQDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingQDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingQDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCQDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingQDA, fmt="--", linewidth=1, yerr=desvPadSemBeamformingQDA, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingQDA, fmt="--", linewidth=1, yerr=desvPadComBeamformingQDA, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCQDA, fmt="--", linewidth=1, yerr=desvPadComGSCQDA, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ## Gerando um CSV para fazer a tabela

# %%
# PARAMETROS INICIAIS
colunas = ["Algoritmo", "Abordagem", "-10 dB", "0 dB", "10 dB", "20 dB", "30 dB"]
data    = []
arrayIndexesSNRsDesejadas = []
for indexSNR, snr in enumerate(rangeSNRs):
    if snr in [-10, 0, 10, 20, 30]:
        arrayIndexesSNRsDesejadas.append(indexSNR)


# COMECANDO
linha = ["KNN", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingKNN[i])[0:5] + " ± " + str(desvPadSemBeamformingKNN[i])[0:5])
data.append(linha)
linha = ["KNN", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingKNN[i])[0:5] + " ± " + str(desvPadComBeamformingKNN[i])[0:5])
data.append(linha)
linha = ["KNN", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCKNN[i])[0:5] + " ± " + str(desvPadComGSCKNN[i])[0:5])
data.append(linha)



linha = ["Perceptron", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingPerceptron[i])[0:5] + " ± " + str(desvPadSemBeamformingPerceptron[i])[0:5])
data.append(linha)
linha = ["Perceptron", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingPerceptron[i])[0:5] + " ± " + str(desvPadComBeamformingPerceptron[i])[0:5])
data.append(linha)
linha = ["Perceptron", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCPerceptron[i])[0:5] + " ± " + str(desvPadComGSCPerceptron[i])[0:5])
data.append(linha)



linha = ["SGD", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingSGD[i])[0:5] + " ± " + str(desvPadSemBeamformingSGD[i])[0:5])
data.append(linha)
linha = ["SGD", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingSGD[i])[0:5] + " ± " + str(desvPadComBeamformingSGD[i])[0:5])
data.append(linha)
linha = ["SGD", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCSGD[i])[0:5] + " ± " + str(desvPadComGSCSGD[i])[0:5])
data.append(linha)



linha = ["LDA", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingLDA[i])[0:5] + " ± " + str(desvPadSemBeamformingLDA[i])[0:5])
data.append(linha)
linha = ["LDA", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingLDA[i])[0:5] + " ± " + str(desvPadComBeamformingLDA[i])[0:5])
data.append(linha)
linha = ["LDA", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCLDA[i])[0:5] + " ± " + str(desvPadComGSCLDA[i])[0:5])
data.append(linha)


linha = ["SVM", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingSVM[i])[0:5] + " ± " + str(desvPadSemBeamformingSVM[i])[0:5])
data.append(linha)
linha = ["SVM", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingSVM[i])[0:5] + " ± " + str(desvPadComBeamformingSVM[i])[0:5])
data.append(linha)
linha = ["SVM", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCSVM[i])[0:5] + " ± " + str(desvPadComGSCSVM[i])[0:5])
data.append(linha)



linha = ["Tree", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingTree[i])[0:5] + " ± " + str(desvPadSemBeamformingTree[i])[0:5])
data.append(linha)
linha = ["Tree", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingTree[i])[0:5] + " ± " + str(desvPadComBeamformingTree[i])[0:5])
data.append(linha)
linha = ["Tree", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCTree[i])[0:5] + " ± " + str(desvPadComGSCTree[i])[0:5])
data.append(linha)



linha = ["QDA", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingQDA[i])[0:5] + " ± " + str(desvPadSemBeamformingQDA[i])[0:5])
data.append(linha)
linha = ["QDA", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingQDA[i])[0:5] + " ± " + str(desvPadComBeamformingQDA[i])[0:5])
data.append(linha)
linha = ["QDA", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCQDA[i])[0:5] + " ± " + str(desvPadComGSCQDA[i])[0:5])
data.append(linha)



# GERANDO O DATAFRAME E SALVANDO COMO CSV
dataframe = pd.DataFrame(data=data, columns=colunas)
dataframe.to_csv(diretorioOrigem + "graficosEmTabela.csv", index=False)
dataframe
