# %% [markdown]
# # Análise dos resultados das simulações de arrays de microfones com o SESA

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## ACESSANDO OS DADOS

# %% [markdown]
# Os resultados serão organizados no dicionário a seguir que segue a estrutura:
#
# **1ª dimensão:** SNR
#
# **2ª dimensão:** Classificador
#
# **3ª dimensão:** Tipo de Beamforming
#
# **4ª dimensão:** Array com acurácias

# %%
dicionarioDados = {
	"SNR_-10dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},    
	"SNR_-9dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-8dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-7dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-6dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-5dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-4dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-3dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-2dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_-1dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_0dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_1dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_2dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_3dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_4dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_5dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_6dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_7dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_8dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_9dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_10dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_11dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_12dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_13dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_14dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_15dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_16dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_17dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_18dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_19dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_20dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_21dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_22dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_23dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_24dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_25dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_26dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_27dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_28dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_29dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	},
	"SNR_30dB": {
		"KNeighborsClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SGDClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"Perceptron": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"SVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"DecisionTreeClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"QuadraticDiscriminantAnalysis": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"BaggingClassifier": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		},
		"LinearSVC": {
			"semBeamforming": [],
			"beamforming": [],
			"GSC": []
		}
	}
}

# %% [markdown]
# ## Começando

# %%
rangeSNRs = list(np.arange(-10, 31, 1))

# %%
# ORIGEM DE ONDE VAO ESTAR AS PASTAS COM OS SNRS CHEIOS DE RELATORIOS DE CLASSIFICADORES
diretorioOrigem  = "/home/dimi/Programming/IC2019/ML/relatorios_classificacao/SESA_Normalizado/graficosACCxSNR/RBRANCO_DIFUSO/original_dataset/com_gridsearch/"

# PARA CADA PASTA DE SNR
for SNRAtual in rangeSNRs:
    
    # PEGANDO OS NOMES DE TODOS OS JSONS DENTRO DESSA PASTA DE SNR ATUAL
    diretorioSNRAtual = diretorioOrigem + "SNR_" + str(SNRAtual) + "dB/"
    arrayArquivosJSONSNRAtual = [arquivo for arquivo in os.listdir(diretorioSNRAtual) if arquivo.endswith(".json")]
    
    # PARA CADA JSON
    for nomeJSONAtual in arrayArquivosJSONSNRAtual:
        
        # EU ABRO O JSON
        with open(diretorioSNRAtual + nomeJSONAtual) as arquivoJSON:
            dadosJSON = json.load(arquivoJSON)

            # PEGO A ACURACIA ATUAL
            acuraciaAtual = dadosJSON["accuracy"]

            # VERIFICO ONDE EU TENHO QUE COLOCAR NO DICIONARIO
            keySNR         = "SNR_" + str(SNRAtual) + "dB"
            classificador  = dadosJSON["classificador"]
            tipoBeamfoming = nomeJSONAtual.split("_")[2]
            
            # E COLOCO NO LUGAR CERTO 
            dicionarioDados[keySNR][classificador][tipoBeamfoming].append(acuraciaAtual)

# %% [markdown]
# ## Analisando os resultados

# %%
#DEFININDO ALGUNS PARÂMETROS PARA PLOTAR GRÁFICOS
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
params = {'figure.figsize': [12, 6], 
          'axes.labelsize': 12,
          'axes.titlesize':16, 
          'font.size': 12,
          'legend.fontsize': 12, 
          'xtick.labelsize': 10, 
          'ytick.labelsize': 10
         }

plt.rcParams.update(params)

# %% [markdown]
# ### KNN

# %%
classificador = "KNeighborsClassifier"

mediaAcuraciasSemBeamformingKNN = []
mediaAcuraciasComBeamformingKNN = []
mediaAcuraciasComGSCKNN         = []
desvPadSemBeamformingKNN        = []
desvPadComBeamformingKNN        = []
desvPadComGSCKNN                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingKNN.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingKNN.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCKNN.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingKNN.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingKNN.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCKNN.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingKNN, fmt="--", linewidth=1, yerr=desvPadSemBeamformingKNN, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingKNN, fmt="--", linewidth=1, yerr=desvPadComBeamformingKNN, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCKNN, fmt="--", linewidth=1, yerr=desvPadComGSCKNN, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "SGDClassifier"

mediaAcuraciasSemBeamformingSGD = []
mediaAcuraciasComBeamformingSGD = []
mediaAcuraciasComGSCSGD         = []
desvPadSemBeamformingSGD        = []
desvPadComBeamformingSGD        = []
desvPadComGSCSGD                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingSGD.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingSGD.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCSGD.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingSGD.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingSGD.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCSGD.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingSGD, fmt="--", linewidth=1, yerr=desvPadSemBeamformingSGD, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingSGD, fmt="--", linewidth=1, yerr=desvPadComBeamformingSGD, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCSGD, fmt="--", linewidth=1, yerr=desvPadComGSCSGD, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "Perceptron"

mediaAcuraciasSemBeamformingPerceptron = []
mediaAcuraciasComBeamformingPerceptron = []
mediaAcuraciasComGSCPerceptron         = []
desvPadSemBeamformingPerceptron        = []
desvPadComBeamformingPerceptron        = []
desvPadComGSCPerceptron                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingPerceptron.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingPerceptron.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCPerceptron.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingPerceptron.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingPerceptron.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCPerceptron.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingPerceptron, fmt="--", linewidth=1, yerr=desvPadSemBeamformingPerceptron, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingPerceptron, fmt="--", linewidth=1, yerr=desvPadComBeamformingPerceptron, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCPerceptron, fmt="--", linewidth=1, yerr=desvPadComGSCPerceptron, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "SVC"

mediaAcuraciasSemBeamformingSVM = []
mediaAcuraciasComBeamformingSVM = []
mediaAcuraciasComGSCSVM         = []
desvPadSemBeamformingSVM        = []
desvPadComBeamformingSVM        = []
desvPadComGSCSVM                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingSVM.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingSVM.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCSVM.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingSVM.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingSVM.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCSVM.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
#plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingSVM, fmt="--", linewidth=1, yerr=desvPadSemBeamformingSVM, elinewidth=0.75, capsize=2, label="No Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingSVM, fmt="--", linewidth=1, yerr=desvPadComBeamformingSVM, elinewidth=0.75, capsize=2, label="Delay Sum")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCSVM, fmt="--", linewidth=1, yerr=desvPadComGSCSVM, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Accuracy")

plt.grid(alpha=0.5)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "LinearDiscriminantAnalysis"

mediaAcuraciasSemBeamformingLDA = []
mediaAcuraciasComBeamformingLDA = []
mediaAcuraciasComGSCLDA         = []
desvPadSemBeamformingLDA        = []
desvPadComBeamformingLDA        = []
desvPadComGSCLDA                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingLDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingLDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCLDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingLDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingLDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCLDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingLDA, fmt="--", linewidth=1, yerr=desvPadSemBeamformingLDA, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingLDA, fmt="--", linewidth=1, yerr=desvPadComBeamformingLDA, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCLDA, fmt="--", linewidth=1, yerr=desvPadComGSCLDA, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "DecisionTreeClassifier"

mediaAcuraciasSemBeamformingTree = []
mediaAcuraciasComBeamformingTree = []
mediaAcuraciasComGSCTree         = []
desvPadSemBeamformingTree        = []
desvPadComBeamformingTree        = []
desvPadComGSCTree                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingTree.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingTree.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCTree.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingTree.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingTree.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCTree.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingTree, fmt="--", linewidth=1, yerr=desvPadSemBeamformingTree, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingTree, fmt="--", linewidth=1, yerr=desvPadComBeamformingTree, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCTree, fmt="--", linewidth=1, yerr=desvPadComGSCTree, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %%
classificador = "QuadraticDiscriminantAnalysis"

mediaAcuraciasSemBeamformingQDA = []
mediaAcuraciasComBeamformingQDA = []
mediaAcuraciasComGSCQDA         = []
desvPadSemBeamformingQDA        = []
desvPadComBeamformingQDA        = []
desvPadComGSCQDA                = []

for snr in rangeSNRs:
    mediaAcuraciasSemBeamformingQDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    mediaAcuraciasComBeamformingQDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    mediaAcuraciasComGSCQDA.append(np.mean(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))
    desvPadSemBeamformingQDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["semBeamforming"]))
    desvPadComBeamformingQDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["beamforming"]))
    desvPadComGSCQDA.append(np.std(dicionarioDados["SNR_" + str(snr) + "dB"][classificador]["GSC"]))

# PLOTANDO
plt.title(classificador)

plt.errorbar(rangeSNRs, mediaAcuraciasSemBeamformingQDA, fmt="--", linewidth=1, yerr=desvPadSemBeamformingQDA, elinewidth=0.75, capsize=2, label="Sem Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComBeamformingQDA, fmt="--", linewidth=1, yerr=desvPadComBeamformingQDA, elinewidth=0.75, capsize=2, label="Com Beamforming")
plt.errorbar(rangeSNRs, mediaAcuraciasComGSCQDA, fmt="--", linewidth=1, yerr=desvPadComGSCQDA, elinewidth=0.75, capsize=2, label="Com GSC")

plt.legend()

plt.xlim(rangeSNRs[0] - 1, rangeSNRs[-1] + 1)
plt.ylim(0.35, 0.95)

plt.xlabel("SNR")
plt.ylabel("Acurácia")

plt.grid(alpha=0.25)

plt.savefig(diretorioOrigem + "resultado_" + classificador + ".pdf", format='pdf', bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ## Gerando um CSV para fazer a tabela

# %%
# PARAMETROS INICIAIS
colunas = ["Algoritmo", "Abordagem", "-10 dB", "0 dB", "10 dB", "20 dB", "30 dB"]
data    = []
arrayIndexesSNRsDesejadas = []
for indexSNR, snr in enumerate(rangeSNRs):
    if snr in [-10, 0, 10, 20, 30]:
        arrayIndexesSNRsDesejadas.append(indexSNR)


# COMECANDO
linha = ["KNN", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingKNN[i])[0:5] + " ± " + str(desvPadSemBeamformingKNN[i])[0:5])
data.append(linha)
linha = ["KNN", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingKNN[i])[0:5] + " ± " + str(desvPadComBeamformingKNN[i])[0:5])
data.append(linha)
linha = ["KNN", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCKNN[i])[0:5] + " ± " + str(desvPadComGSCKNN[i])[0:5])
data.append(linha)



linha = ["Perceptron", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingPerceptron[i])[0:5] + " ± " + str(desvPadSemBeamformingPerceptron[i])[0:5])
data.append(linha)
linha = ["Perceptron", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingPerceptron[i])[0:5] + " ± " + str(desvPadComBeamformingPerceptron[i])[0:5])
data.append(linha)
linha = ["Perceptron", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCPerceptron[i])[0:5] + " ± " + str(desvPadComGSCPerceptron[i])[0:5])
data.append(linha)



linha = ["SGD", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingSGD[i])[0:5] + " ± " + str(desvPadSemBeamformingSGD[i])[0:5])
data.append(linha)
linha = ["SGD", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingSGD[i])[0:5] + " ± " + str(desvPadComBeamformingSGD[i])[0:5])
data.append(linha)
linha = ["SGD", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCSGD[i])[0:5] + " ± " + str(desvPadComGSCSGD[i])[0:5])
data.append(linha)



linha = ["LDA", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingLDA[i])[0:5] + " ± " + str(desvPadSemBeamformingLDA[i])[0:5])
data.append(linha)
linha = ["LDA", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingLDA[i])[0:5] + " ± " + str(desvPadComBeamformingLDA[i])[0:5])
data.append(linha)
linha = ["LDA", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCLDA[i])[0:5] + " ± " + str(desvPadComGSCLDA[i])[0:5])
data.append(linha)


linha = ["SVM", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingSVM[i])[0:5] + " ± " + str(desvPadSemBeamformingSVM[i])[0:5])
data.append(linha)
linha = ["SVM", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingSVM[i])[0:5] + " ± " + str(desvPadComBeamformingSVM[i])[0:5])
data.append(linha)
linha = ["SVM", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCSVM[i])[0:5] + " ± " + str(desvPadComGSCSVM[i])[0:5])
data.append(linha)



linha = ["Tree", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingTree[i])[0:5] + " ± " + str(desvPadSemBeamformingTree[i])[0:5])
data.append(linha)
linha = ["Tree", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingTree[i])[0:5] + " ± " + str(desvPadComBeamformingTree[i])[0:5])
data.append(linha)
linha = ["Tree", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCTree[i])[0:5] + " ± " + str(desvPadComGSCTree[i])[0:5])
data.append(linha)



linha = ["QDA", "Sem beamforming"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasSemBeamformingQDA[i])[0:5] + " ± " + str(desvPadSemBeamformingQDA[i])[0:5])
data.append(linha)
linha = ["QDA", "Delay Sum"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComBeamformingQDA[i])[0:5] + " ± " + str(desvPadComBeamformingQDA[i])[0:5])
data.append(linha)
linha = ["QDA", "GSC"]
for i in arrayIndexesSNRsDesejadas:
    linha.append(str(mediaAcuraciasComGSCQDA[i])[0:5] + " ± " + str(desvPadComGSCQDA[i])[0:5])
data.append(linha)



# GERANDO O DATAFRAME E SALVANDO COMO CSV
dataframe = pd.DataFrame(data=data, columns=colunas)
dataframe.to_csv(diretorioOrigem + "graficosEmTabela.csv", index=False)
dataframe
# Out:
#      Algoritmo        Abordagem         -10 dB           0 dB          10 dB  \
# 0          KNN  Sem beamforming  0.697 ± 0.018  0.796 ± 0.014  0.847 ± 0.019
# 1          KNN        Delay Sum  0.769 ± 0.016  0.820 ± 0.007  0.836 ± 0.009
# 2          KNN              GSC  0.750 ± 0.018  0.822 ± 0.004  0.838 ± 0.019
# 3   Perceptron  Sem beamforming  0.582 ± 0.058  0.710 ± 0.029  0.744 ± 0.037
# 4   Perceptron        Delay Sum  0.659 ± 0.055  0.740 ± 0.018  0.763 ± 0.035
# 5   Perceptron              GSC  0.649 ± 0.050  0.735 ± 0.025  0.769 ± 0.029
# 6          SGD  Sem beamforming  0.714 ± 0.023  0.754 ± 0.016  0.796 ± 0.009
# 7          SGD        Delay Sum  0.708 ± 0.012  0.784 ± 0.011  0.824 ± 0.015
# 8          SGD              GSC   0.72 ± 0.007  0.775 ± 0.011  0.830 ± 0.007
# 9          LDA  Sem beamforming  0.622 ± 0.011  0.697 ± 0.013  0.739 ± 0.011
# 10         LDA        Delay Sum  0.645 ± 0.011  0.716 ± 0.018  0.731 ± 0.016
# 11         LDA              GSC   0.64 ± 0.007  0.704 ± 0.010  0.723 ± 0.008
# 12         SVM  Sem beamforming  0.775 ± 0.014  0.775 ± 0.012  0.843 ± 0.004
# 13         SVM        Delay Sum  0.819 ± 0.013  0.828 ± 0.008  0.847 ± 0.010
# 14         SVM              GSC  0.817 ± 0.012  0.824 ± 0.009  0.845 ± 0.011
# 15        Tree  Sem beamforming  0.651 ± 0.031  0.754 ± 0.026  0.798 ± 0.037
# 16        Tree        Delay Sum  0.657 ± 0.028  0.775 ± 0.034  0.819 ± 0.044
# 17        Tree              GSC  0.662 ± 0.037  0.779 ± 0.044  0.819 ± 0.026
# 18         QDA  Sem beamforming  0.392 ± 0.003  0.660 ± 0.009  0.672 ± 0.009
# 19         QDA        Delay Sum  0.428 ± 0.010  0.685 ± 0.006  0.803 ± 0.009
# 20         QDA              GSC  0.409 ± 0.010  0.678 ± 0.003  0.798 ± 0.007
#
#             20 dB          30 dB
# 0   0.840 ± 0.011  0.840 ± 0.007
# 1   0.840 ± 0.011  0.849 ± 0.003
# 2   0.855 ± 0.015  0.838 ± 0.006
# 3   0.754 ± 0.015  0.676 ± 0.073
# 4   0.771 ± 0.046  0.769 ± 0.058
# 5    0.76 ± 0.058  0.767 ± 0.064
# 6   0.819 ± 0.008  0.767 ± 0.029
# 7   0.853 ± 0.007  0.824 ± 0.012
# 8   0.841 ± 0.009  0.824 ± 0.012
# 9   0.786 ± 0.012  0.744 ± 0.007
# 10  0.767 ± 0.009  0.777 ± 0.007
# 11  0.777 ± 0.007  0.775 ± 0.004
# 12  0.840 ± 0.007  0.803 ± 0.004
# 13  0.855 ± 0.013  0.849 ± 0.007
# 14  0.860 ± 0.015  0.853 ± 0.007
# 15  0.742 ± 0.045  0.668 ± 0.013
# 16  0.822 ± 0.026  0.796 ± 0.029
# 17  0.826 ± 0.016  0.798 ± 0.033
# 18  0.615 ± 0.009  0.535 ± 0.011
# 19  0.758 ± 0.004  0.754 ± 0.007
# 20  0.763 ± 0.003  0.737 ± 0.009
